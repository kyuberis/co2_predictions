# %%
import sys, os, site, pathlib

print("sys.executable =", sys.executable)
print("VIRTUAL_ENV    =", os.environ.get("VIRTUAL_ENV"))
print("site-packages  =", site.getsitepackages())
print("cwd            =", pathlib.Path().resolve())
# Out:
# sys.executable = c:\Users\kyube\co2-forecasting\.venv\Scripts\python.exe
# VIRTUAL_ENV    = C:\Users\kyube\co2-forecasting\.venv
# site-packages  = ['c:\\Users\\kyube\\co2-forecasting\\.venv', 'c:\\Users\\kyube\\co2-forecasting\\.venv\\lib\\site-packages']
# cwd            = C:\Users\kyube\co2-forecasting\notebooks

# %%
import importlib.util as iu

mods = ["numpy","pandas","requests","matplotlib","sklearn","lightgbm"]
for m in mods:
    print(m, "->", "OK" if iu.find_spec(m) else "MISSING")
# Out:
# numpy -> OK
# pandas -> OK
# requests -> OK
# matplotlib -> OK
# sklearn -> OK
# lightgbm -> OK
